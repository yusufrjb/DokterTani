# %%
import pandas as pd

# Data kondisi tumbuhan cabe
plant_conditions = {
    'kode_gejala': ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17'],
    'gejala': ['batang bercak hitam', 'batang bercak coklat', 'batang membusuk', 'batang layu', 'batang menguning',
               'daun bercak hitam', 'daun bercak coklat', 'daun layu', 'daun bercak putih', 'daun keriting', 'daun menguning',
               'buah bercak hitam', 'buah membusuk', 'buah bercak coklat', 'buah layu', 'buah berjamur', 'buah menguning']
}

# Data penyakit
diseases = {
    'kode_penyakit': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9'],
    'penyakit': ['Anthracnose Buah / patek', 'Busuk Phytopthora', 'Rebah Semai', 'Penyakit Layu Fusarium',
                 'Bercak Daun', 'Virus mozaik', 'Busuk Cabang', 'Busuk Kuncup', 'Virus Gemini']
}

# Definisikan aturan-aturan Decision Tree
rules = {
    'R1': (['G12', 'G13'], 'P1'),
    'R2': (['G1', 'G2', 'G6', 'G7', 'G12', 'G14'], 'P2'),
    'R3': (['G3'], 'P3'),
    'R4': (['G4', 'G8', 'G15'], 'P4'),
    'R5': (['G7', 'G9'], 'P5'),
    'R6': (['G10', 'G11'], 'P6'),
    'R7': (['G4'], 'P7'),
    'R8': (['G13'], 'P8'),
    'R9': (['G5', 'G11', 'G17'], 'P9'),
    'R10': (['G1', 'G2'], 'P2'),
    'R11': (['G1', 'G6'], 'P2'),
    'R12': (['G1', 'G7'], 'P2'),
    'R13': (['G1', 'G12'], 'P2'),
    'R14': (['G1', 'G14'], 'P2'),
    'R15': (['G2', 'G6'], 'P2'),
    'R16': (['G2', 'G7'], 'P2'),
    'R17': (['G2', 'G12'], 'P2'),
    'R18': (['G2', 'G14'], 'P2'),
    'R19': (['G6', 'G7'], 'P2'),
    'R20': (['G6', 'G12'], 'P2'),
    'R21': (['G6', 'G14'], 'P2'),
    'R22': (['G7', 'G12'], 'P2'),
    'R23': (['G7', 'G14'], 'P2'),
    'R24': (['G12', 'G14'], 'P2'),
    'R25': (['G1', 'G2', 'G6'], 'P2'),
    'R26': (['G1', 'G2', 'G7'], 'P2'),
    'R27': (['G1', 'G2', 'G12'], 'P2'),
    'R28': (['G1', 'G2', 'G14'], 'P2'),
    'R29': (['G1', 'G6', 'G7'], 'P2'),
    'R30': (['G1', 'G6', 'G12'], 'P2'),
    'R31': (['G1', 'G6', 'G14'], 'P2'),
    'R32': (['G1', 'G7', 'G12'], 'P2'),
    'R33': (['G1', 'G7', 'G14'], 'P2'),
    'R34': (['G1', 'G12', 'G14'], 'P2'),
    'R35': (['G2', 'G6', 'G7'], 'P2'),
    'R36': (['G2', 'G6', 'G12'], 'P2'),
    'R37': (['G2', 'G6', 'G14'], 'P2'),
    'R38': (['G2', 'G7', 'G12'], 'P2'),
    'R39': (['G2', 'G7', 'G14'], 'P2'),
    'R40': (['G2', 'G12', 'G14'], 'P2'),
    'R41': (['G6', 'G7', 'G12'], 'P2'),
    'R42': (['G6', 'G7', 'G14'], 'P2'),
    'R43': (['G6', 'G12', 'G14'], 'P2'),
    'R44': (['G7', 'G12', 'G14'], 'P2'),
    'R45': (['G1', 'G2', 'G6', 'G7'], 'P2'),
    'R46': (['G1', 'G2', 'G6', 'G12'], 'P2'),
    'R47': (['G1', 'G2', 'G6', 'G14'], 'P2'),
    'R48': (['G1', 'G2', 'G7', 'G12'], 'P2'),
    'R49': (['G1', 'G2', 'G7', 'G14'], 'P2'),
    'R50': (['G1', 'G2', 'G12', 'G14'], 'P2'),
    'R51': (['G1', 'G6', 'G7', 'G12'], 'P2'),
    'R52': (['G1', 'G6', 'G7', 'G14'], 'P2'),
    'R53': (['G1', 'G6', 'G12', 'G14'], 'P2'),
    'R54': (['G1', 'G7', 'G12', 'G14'], 'P2'),
    'R55': (['G2', 'G6', 'G7', 'G12'], 'P2'),
    'R56': (['G2', 'G6', 'G7', 'G14'], 'P2'),
    'R57': (['G2', 'G6', 'G12', 'G14'], 'P2'),
    'R58': (['G2', 'G7', 'G12', 'G14'], 'P2'),
    'R59': (['G6', 'G7', 'G12', 'G14'], 'P2'),
    'R60': (['G1', 'G2', 'G6', 'G7', 'G12'], 'P2'),
    'R61': (['G1', 'G2', 'G6', 'G7', 'G14'], 'P2'),
    'R62': (['G1', 'G2', 'G6', 'G12', 'G14'], 'P2'),
    'R63': (['G1', 'G2', 'G7', 'G12', 'G14'], 'P2'),
    'R64': (['G1', 'G6', 'G7', 'G12', 'G14'], 'P2'),
    'R65': (['G2', 'G6', 'G7', 'G12', 'G14'], 'P2'),
    'R66': (['G1', 'G2', 'G6', 'G7', 'G12', 'G14'], 'P2'),
    'R67': (['G3'], 'P3'),
    'R68': (['G4'], 'P4'),
    'R69': (['G8'], 'P4'),
    'R70': (['G15'], 'P4'),
    'R71': (['G4', 'G8'], 'P4'),
    'R72': (['G4', 'G15'], 'P4'),
    'R73': (['G8', 'G15'], 'P4'),
    'R74': (['G4', 'G8', 'G15'], 'P4'),
    'R75': (['G7'], 'P5'),
    'R76': (['G9'], 'P5'),
    'R77': (['G7', 'G9'], 'P5'),
    'R78': (['G10'], 'P6'),
    'R79': (['G11'], 'P6'),
    'R80': (['G10', 'G11'], 'P6'),
    'R81': (['G4'], 'P7'),
    'R82': (['G13'], 'P7'),
    'R83': (['G16'], 'P7'),
    'R84': (['G4', 'G13'], 'P7'),
    'R85': (['G4', 'G16'], 'P7'),
    'R86': (['G13', 'G16'], 'P7'),
    'R87': (['G4', 'G13', 'G16'], 'P7'),
    'R88': (['G13'], 'P8'),
    'R89': (['G16'], 'P8'),
    'R90': (['G13', 'G16'], 'P8'),
    'R91': (['G5'], 'P9'),
    'R92': (['G11'], 'P9'),
    'R93': (['G17'], 'P9'),
    'R94': (['G5', 'G11'], 'P9'),
    'R95': (['G5', 'G17'], 'P9'),
    'R96': (['G11', 'G17'], 'P9'),
    'R97': (['G5', 'G11', 'G17'], 'P9')
}

# Konversi data menjadi DataFrame
df_plant_conditions = pd.DataFrame(plant_conditions)
df_diseases = pd.DataFrame(diseases, columns=['kode_penyakit', 'penyakit'])
df_rules = pd.DataFrame(rules.items(), columns=['rules', 'condition_disease'])

# Fungsi untuk memprediksi penyakit berdasarkan gejala
def predict_disease(symptoms):
    predicted_diseases = []
    for index, row in df_plant_conditions.iterrows():
        if row['gejala'] in symptoms:
            condition_code = row['kode_gejala']
            diseases_for_condition = df_rules[df_rules['condition_disease'].apply(lambda x: condition_code in x[0])]['condition_disease'].apply(lambda x: x[1])
            predicted_diseases.extend(df_diseases[df_diseases['kode_penyakit'].isin(diseases_for_condition)]['penyakit'].tolist())
    if predicted_diseases:
        return predicted_diseases
    else:
        return ["Penyakit tidak ditemukan"]

# Contoh penggunaan fungsi untuk memprediksi penyakit berdasarkan gejala
symptoms =['buah bercak hitam','buah membusuk']
predicted_diseases = predict_disease(symptoms)
print("Prediksi penyakit:", predicted_diseases)
# Out:
# Prediksi penyakit: ['Anthracnose Buah / patek', 'Busuk Phytopthora', 'Anthracnose Buah / patek', 'Busuk Cabang', 'Busuk Kuncup']

# %%
import pickle

# Simpan DataFrame ke dalam model pickle
with open('model_plant_conditions.pkl', 'wb') as f:
    pickle.dump(df_plant_conditions, f)

with open('model_diseases.pkl', 'wb') as f:
    pickle.dump(df_diseases, f)

with open('model_rules.pkl', 'wb') as f:
    pickle.dump(df_rules, f)

# %%
import pickle
import pandas as pd

# Muat model DataFrame dari file pickle
with open('model_plant_conditions.pkl', 'rb') as f:
    df_plant_conditions = pickle.load(f)

with open('model_diseases.pkl', 'rb') as f:
    df_diseases = pickle.load(f)

with open('model_rules.pkl', 'rb') as f:
    df_rules = pickle.load(f)

# Fungsi untuk memprediksi penyakit berdasarkan gejala
def predict_disease(symptoms):
    predicted_diseases = []
    for index, row in df_plant_conditions.iterrows():
        if row['gejala'] in symptoms:
            condition_code = row['kode_gejala']
            diseases_for_condition = df_rules[df_rules['condition_disease'].apply(lambda x: condition_code in x[0])]['condition_disease'].apply(lambda x: x[1])
            predicted_diseases.extend(df_diseases[df_diseases['kode_penyakit'].isin(diseases_for_condition)]['penyakit'].tolist())
    if predicted_diseases:
        return predicted_diseases
    else:
        return ["Penyakit tidak ditemukan"]

# Contoh penggunaan fungsi untuk memprediksi penyakit berdasarkan gejala
symptoms = ['buah bercak hitam', 'buah membusuk']
predicted_diseases = predict_disease(symptoms)
print("Prediksi penyakit:", predicted_diseases)
# Out:
# Prediksi penyakit: ['Anthracnose Buah / patek', 'Busuk Phytopthora', 'Anthracnose Buah / patek', 'Busuk Cabang', 'Busuk Kuncup']
